# %%
# %run "dN_dm_Distribution.ipynb"
# %run "pm_star_model.ipynb"
# Out:
# r-i: 2.1923610639150937
# i-z: 3.5768177213354715
# z-Y: 1.4191546795670078
# r-J = [5.25572474 5.50904351 5.41718128 5.37948205 5.42316845 5.56927788
#  5.26496108]
# i-J = [2.75113147 3.20651059 3.21190886 3.2466879  3.33150873 3.48301067
#  3.16439754]
# z-J = [1.09224856 1.20381612 1.01827933 0.83094998 0.65335281 0.49738689
#  0.14358936]
# Y-J = [ 0.36949653  0.33151962  0.0706143  -0.1931262  -0.45694834 -0.71874101
#  -1.066992  ]
# [ 1.11602513  0.39061241  0.42566314  0.49893841  0.58843439  0.70378447
#  -0.31241808]
# [ 1.41372431  0.49703394  0.51376259  0.5557955   0.61384615  0.68915774
#  -0.326384  ]
# [ 0.90483804  0.31829709  0.31062933  0.31471195  0.33009372  0.35797444
#  -0.06556951]
# [0.68305475 0.24099144 0.23719791 0.2353211  0.23703462 0.23938005
#  0.06411796]
# Star moving parallel to sun test passed
# Star at equator with v_phi=0 test passed

# %%
from matplotlib.colors import LogNorm

# %%
plt.ylabel(r"$\log{pm}$", fontsize=18)
plt.xlabel("$m_z$", fontsize=18)
# plt.yscale("log")
plt.title("2D Histogram of Proper Motion vs. \n Apparent Magnitude in Z-band", fontsize=18)
# change bins in Y to log or take log of y-axis, and label log of pm
hist_Z = plt.hist2d(m_Z, np.log10(pm), bins=100, density=True, norm=LogNorm())
plt.colorbar()
plt.tight_layout()
plt.savefig("pm_mag_z_band_2D_hist.png", dpi=600)
plt.tick_params(axis='both', labelsize=16)
plt.show()

# %%
plt.ylabel(r"$\log{pm}$", fontsize=18)
plt.xlabel("$m_Y$", fontsize=18)
plt.title("2D Histogram of Proper Motion vs. \n Apparent Magnitude in Y-band", fontsize=18)
hist_Y = plt.hist2d(m_Y, np.log10(pm), bins=100, density=True, norm=LogNorm())
plt.colorbar()
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.savefig("pm_mag_Y_band_2D_hist.png", dpi=600)
plt.show()

# %%
plt.ylabel(r"$\log{pm}$", fontsize=18)
plt.xlabel("$m_J$", fontsize=18)
plt.title("2D Histogram of Proper Motion vs. \n Apparent Magnitude in J-band", fontsize=18)
hist_J = plt.hist2d(m_J, np.log10(pm), bins=100, density=True, norm=LogNorm())
plt.colorbar()
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.savefig("pm_mag_J_band_2D_hist.png", dpi=600)
plt.show()
