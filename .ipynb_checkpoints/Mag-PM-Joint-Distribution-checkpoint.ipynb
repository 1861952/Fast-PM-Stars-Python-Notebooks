# %%
# %run "dN_dm_Distribution.ipynb"
# %run "pm_star_model.ipynb"
# Out:
# r-i: 2.893770909142212
# i-z: 3.0871284196913997
# z-Y: 0.6417477655755697
# r-J = [4.69815021 4.92465469 4.81650757 4.75975969 4.78403932 4.9127287
#  4.60493546]
# i-J = [2.17731017 2.49413156 2.4193376  2.35785268 2.32768347 2.34626491
#  2.00380741]
# z-J = [ 0.6243463   0.63201717  0.39684733  0.16078868 -0.07032288 -0.29101642
#  -0.63665925]
# Y-J = [ 0.33080855  0.28505396  0.01672986 -0.25540276 -0.52927079 -0.80325325
#  -1.15743799]
# [ 1.07703899  0.37596997  0.40773578  0.47876845  0.5697908   0.68758797
#  -0.30317446]
# [ 1.20986794  0.42377484  0.42663724  0.45039293  0.48926863  0.54789426
#  -0.23280926]
# [0.74871106 0.26663068 0.26302962 0.26485309 0.27292379 0.28568913
#  0.0230252 ]
# [0.67476652 0.23372429 0.22962752 0.22610723 0.22615671 0.22587837
#  0.06575216]
# Star moving parallel to sun test passed
# Star at equator with v_phi=0 test passed
# 373.21364307370425

# %%
from matplotlib.colors import LogNorm

# %%
plt.ylabel("Proper Motion")
plt.xlabel("$m_z$")
plt.title("2D Histogram of Proper Motion vs. Apparent Magnitude in Z-band")
hist_Z = plt.hist2d(m_Z, pm, bins=100, density=True, norm=LogNorm())
plt.colorbar()

# %%
plt.ylabel("Proper Motion")
plt.xlabel("$m_Y$")
plt.title("2D Histogram of Proper Motion vs. Apparent Magnitude in Y-band")
hist_Y = plt.hist2d(m_Y, pm, bins=100, density=True, norm=LogNorm())
plt.colorbar()

# %%
plt.ylabel("Proper Motion")
plt.xlabel("$m_J$")
plt.title("2D Histogram of Proper Motion vs. Apparent Magnitude in J-band")
hist_J = plt.hist2d(m_J, pm, bins=100, density=True, norm=LogNorm())
plt.colorbar()
